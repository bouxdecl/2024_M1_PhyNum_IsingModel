# %% [markdown]
# # Show scale invariance at T=Tc

# %%
import numpy as np
import scipy
import scipy.signal as signal
import scipy.constants

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %matplotlib notebook
# %matplotlib inline
from IPython.display import HTML
import ipywidgets as widgets


from Ising_class import IsingModel

# %%
Tc = 2.269
model = IsingModel(N=10000, T=Tc)

model.simulate(10000)

model.plot()

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

N = model.N

axes[0, 0].imshow(model.lattice, cmap='gray')
axes[0, 1].imshow(model.lattice[:N//2, :N//2], cmap='gray')
axes[1, 0].imshow(model.lattice[:N//4, :N//4], cmap='gray')
axes[1, 1].imshow(model.lattice[:N//8, :N//8], cmap='gray')
